// %% [markdown]
// # jjava
// * https://github.com/dflib/jjava
//
// > JJava is an evolution of the earlier [IJava kernel](https://github.com/SpencerPark/IJava), that is no longer maintained by its authors.
//
// Kernel file:
// * windows: C:\Users\zhouj\AppData\Roaming\jupyter\kernels\java\kernel.json

// %%
System.out.println("Hello jjava.");
// Out:
// Hello jjava.

// %%
%maven com.google.guava:guava:33.4.0-jre

import com.google.common.collect.*;

Lists.newArrayList("A", "B")
// Out:
// [A, B]

// %% [markdown]
// # process
// * https://www.baeldung.com/java-process-api

// %%
// bootstrap:
// javac *.java

// %%
// // without package declaration: NOT WORKING!!!
// %classpath D:\\GoogleDrive\\wiki\\jupyter-notebooks\\Java\\lib

// Processes.run("java -version");
// Out:
// |   Processes.run("java -version");
// 找不到符号
//   符号:   变量 Processes
//   位置: 类

// %%
// with package declaration
%classpath D:\\GoogleDrive\\wiki\\jupyter-notebooks\\Java\\lib

import util.*;
Processes.run("java -version");
// Out:
// openjdk version "17.0.9" 2023-10-17
// OpenJDK Runtime Environment Temurin-17.0.9+9 (build 17.0.9+9)
// OpenJDK 64-Bit Server VM Temurin-17.0.9+9 (build 17.0.9+9, mixed mode, sharing)

// %% [markdown]
// ## Windows

// %%
Processes.run("HELP");
// Out:
// For more information on a specific command, type HELP command-name
// ASSOC          Displays or modifies file extension associations.
// ATTRIB         Displays or changes file attributes.
// BREAK          Sets or clears extended CTRL+C checking.
// BCDEDIT        Sets properties in boot database to control boot loading.
// CACLS          Displays or modifies access control lists (ACLs) of files.
// CALL           Calls one batch program from another.
// CD             Displays the name of or changes the current directory.
// CHCP           Displays or sets the active code page number.
// CHDIR          Displays the name of or changes the current directory.
// CHKDSK         Checks a disk and displays a status report.
// CHKNTFS        Displays or modifies the checking of disk at boot time.
// CLS            Clears the screen.
// CMD            Starts a new instance of the Windows command interpreter.
// COLOR          Sets the default console foreground and background colors.
// ...

// %%
Processes.run("CMD");
// Out:
// Microsoft Windows [Version 10.0.22631.4751]
// (c) Microsoft Corporation。保留所有权利。

// %% [markdown]
// # Image

// %%
import javax.imageio.ImageIO;
import java.io.File;

// java.awt.image.BufferedImage
ImageIO.read(new File("C:\\Users\\zhouj\\Pictures\\avatar.png"));
// Out:
// BufferedImage@70c745ca: type = 6 ColorModel: #pixelBits = 32 numComponents = 4 color space = java.awt.color.ICC_ColorSpace@2f06ed40 transparency = 3 has alpha = true isAlphaPre = false ByteInterleavedRaster: width = 200 height = 200 #numDataElements 4 dataOff[0] = 3
