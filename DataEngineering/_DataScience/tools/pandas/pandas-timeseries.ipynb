# %%
import pandas as pd

# %%
# %matplotlib inline

# %%
index = pd.DatetimeIndex(['12:00:26', '12:01:26',
                          '12:02:26'])
data = pd.Series([pd.to_datetime('12:05:19'), 
                  pd.to_datetime('12:08:19'), 
                  pd.to_datetime('12:05:39')], index=index)

# %%
data
# Out:
# 2019-09-03 12:00:26   2019-09-03 12:05:19
# 2019-09-03 12:01:26   2019-09-03 12:08:19
# 2019-09-03 12:02:26   2019-09-03 12:05:39
# dtype: datetime64[ns]

# %%
data.plot(kind='line')

# %%
pd.to_datetime('12:09:00')
# Out:
# Timestamp('2019-09-03 12:09:00')
