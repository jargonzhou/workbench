# %%
from parser import JsonSchemaParser
import json
import pandas as pd

# Elasticsearch REST API Specification
# https://github.com/elastic/elasticsearch/tree/main/rest-api-spec
COMMON_DIR = ("D:/workspace/github/application-store/data-engineering/elastic/elasticsearch/rest-api-spec/src/main"
              "/resources")
SCHEMA = COMMON_DIR + "/schema.json"
JSON_DIR = COMMON_DIR + "/rest-api-spec/api"

parser = JsonSchemaParser(JSON_DIR)

apis = parser.parse()
for api in apis:
    print(api)
    # df = pd.json_normalize(json.loads(json.dumps(api, default=vars)))
    # display(df)
    # print(df.to_markdown())

# pd.json_normalize(json.loads(json.dumps(apis, default=vars)))
# Out:
# Name: async_search.delete
# Stability: stable
# Path:
#  DELETE /_async_search/{id}
#  Parts:
#   id:
#     Type: string
#     Description: The async search ID
#     Required: None
#     Options:
#     Deprecated: None
# Headers:
#  Accept: application/json
#  Content-Type: []
# Name: async_search.get
# Stability: stable
# Path:
#  GET /_async_search/{id}
#  Parts:
#   id:
#     Type: string
#     Description: The async search ID
#     Required: None
#     Options:
#     Deprecated: None
# Headers:
#  Accept: application/json
#  Content-Type: []
# Params:
#  wait_for_completion_timeout:
#     Type: time
#     Description: Specify the time that the request should block waiting for the final response
#     Required: None
#     Options:
#     Deprecated: None
#  keep_alive:
#     Type: time
#     Description: Specify the time interval in which the results (partial or final) for this search will be available
#     Required: None
#     Options:
#     Deprecated: None
#  typed_keys:
# ...
