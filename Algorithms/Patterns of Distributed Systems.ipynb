# %% [markdown]
# # Patterns of Distributed Systems
# - Joshi, Unmesh. **Patterns of Distributed Systems**. 2023. Addison-Wesley Professional.
#
# > A concept description, non-creative material, with some illustrative examples.
#
# Contents:
# - Part I: Narratives: 1-2
# - Part II: Patterns of Data Replication: 3-18
# - Part III: Patterns of Data Partitioning: 19-21
# - Part IV: Patterns of Distributed Time: 22-24
# - Part V: Patterns of Cluster Management: 25-29
# - Part VI: Patterns of Communication between Nodes: 30-32
#
# | Title                                           |
# | :-----------------------------------------------|
# | 1 The Promise and Perils of Distributed Systems |
# | 2 Overview of the Patterns                      |
# | 3 Write-Ahead Log                               |
# | 4 Segmented Log                                 |
# | 5 Low-Water Mark                                |
# | 6 Leader and Followers                          |
# | 7 HeartBeat                                     |
# | 8 Majority Quorum                               |
# | 9 Generation Clock                              |
# | 10 High-Water Mark                              |
# | 11 Paxos                                        |
# | 12 Replicated Log                               |
# | 13 Singular Update Queue                        |
# | 14 Request Waiting List                         |
# | 15 Idempotent Receiver                          |
# | 16 Follower Reads                               |
# | 17 Versioned Value                              |
# | 18 Version Vector                               |
# | 19 Fixed Partitions                             |
# | 20 Key-Range Partitions                         |
# | 21 Two-Phase Commit                             |
# | 22 Lamport Clock                                |
# | 23 Hybrid Clock                                 |
# | 24 Clock-Bound Wait                             |
# | 25 Consistent Core                              |
# | 26 Lease                                        |
# | 27 State Watch                                  |
# | 28 Gossip Dissemination                         |
# | 29 Emergent Leader                              |
# | 30 Single-Socket Channel                        |
# | 31 Request Batch                                |
# | 32 Request Pipeline                             |

# %% [markdown]
# # 2 Overview of the Patterns

# %% [markdown]
# Figure 2.1 An example data record
# - boston: 50
# - philadelphia: 38
# - london: 20
# - pune: 75
# Figure 2.2 Replicated data record
# - Jupiter
# - Saturn
# - Neptune
#
# > Keeping Data Resilient on a Sginle Server
#
# WAL(Write-Ahead Log)
#
# > Competing Updates
#
# Leader and Followers
#
# > Dealing with the Leader Failing
#
# HeartBeat
# Majority Quorum
#
# > Multiple Failures Need a Generation Clock
#
# Generation Clock
#
# > Log Entries Cannot Be Committed until They Are Accepted by a Majority Quorum
#
# Replicated Log
#
# > Followers Commit Based on a High-Water Mark
#
# High-Water Mark
#
# > Leaders Use a Series of Queues to Remain Responsive to Many Clients
#
# Sigular Update Queue
# Request Waiting List
#
# > Followers Can Handle Read Requests to Reduce Load on the Leader
#
# Versioned Value
# Hybrid Clock
#
# > A Large Amount of Data Can be Partitioned over Multiple Nodes
#
# Fixed Partitions
# Key-Range Partitions
#
# > Partitions Can Be Replicated for Resilience
#
# > A Minimum of Two Phases Are Needed to Maintain Consistency across Partitions
#
# Two-Phase Commit: for consistency across partitions
#
# > In Distributed Systems, Ordering Cannot Depend on System Timestamps
#
# a single counter
# system timestamp
#
# Lamport Clock
# Hybrid Clock: combine clock time with Lamport Clock
# Clock-Bound Wait
# Read Restart
#
# > A Consistent Core Can Manage the Membership of a Data Cluster
#
# Consistent Core
# Figure 2.53 Consistent Core tracks cluster membership
# - Lease
# - State Watch
#
# > Gossip Dissemination ofr Decentralized Cluster Management
#
# Gossip Dissemination
# seed node

# %% [markdown]
# # TODO

# %% [markdown]
# - [ ] Collect some common solutions, including
# 	- [ ] timeouted request
# 	- [ ] heartbeat
# 	- [ ] connection management
# 	- [ ] session management
